# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from utils import rotate_image, crop_around_center, binarize_images

# %%
img = mpimg.imread('../test_images/car_original.jpg')
plt.imshow(img)

# %%
rot_img = rotate_image(img, 45)
rot_img = crop_around_center(rot_img, 32, 32)
plt.imshow(rot_img)

# %%
import matplotlib
matplotlib.image.imsave('../test_images/car_rotated.jpg', rot_img)

# %%
img = mpimg.imread('../test_images/truck_original.jpg')

rot_img = rotate_image(img, 15)
rot_img = crop_around_center(rot_img, 32, 32)
plt.imshow(rot_img)

matplotlib.image.imsave('../test_images/truck_rotated.jpg', rot_img)

# %%
img = mpimg.imread('../test_images/land_original.jpg')

rot_img = rotate_image(img, 15)
rot_img = crop_around_center(rot_img, 224, 224)
plt.imshow(rot_img)

matplotlib.image.imsave('../test_images/land_rotated.jpg', rot_img)

# %%
import numpy as np
import matplotlib.image as mpimg

img = mpimg.imread('../test_images/land_original.jpg')
img = img.astype(float)

def binarize_images(x):
    """
    Convert images to range 0-1 and binarize them by making
    0 the values below 0.1 and 1 the values above 0.1.
    """
    x /= 255
    x[x >= 0.1] = 1
    x[x < 0.1] = 0

    return x

img = binarize_images(img)
print(np.mean(img))
# Out:
# 0.953390731293

# %%
img
# Out:
# array([[[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...
